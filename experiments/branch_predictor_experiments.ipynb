# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Gshare: misprediction rate plots for different traces and configs

# %%
ghistorybits = [num_bits for num_bits in range(5, 16)]

int_1 = [35.57, 35.94, 34.23, 30.91, 26.11, 22.02, 19.09, 16.19, 13.84, 12.2, 11.2]
int_2 = [1.98, 1.71, 1.54, 1.26, 0.97, 0.73, 0.58, 0.50, 0.42, 0.401, 0.364]

mm_1 = [31.25, 29.89, 27.31, 22.5, 16.65, 13.1, 9.89, 7.88, 6.696, 5.33, 4.44]
mm_2 = [24.1, 21.41, 19.63, 17.63, 15.15, 13.31, 11.91, 10.93, 10.14, 9.09, 8.04]

fp_1 = [2.68, 2.31, 1.85, 1.65, 1.47, 1.22, 1.17, 1, 0.83, 0.83, 0.83]
fp_2 = [19.6, 17.64, 15.19, 11.45, 10.73, 6.13, 5.39, 3.36, 1.68, 1.36, 0.99]

# %%
# make plot for gshare 
plt.figure(figsize=(11, 6), dpi=200)
plt.plot(ghistorybits, int_1, c = 'b', label = "int_1")
plt.plot(ghistorybits, int_2, c = 'g', label = "int_2")
plt.plot(ghistorybits, mm_1, c = 'y', label = "mm_1")
plt.plot(ghistorybits, mm_2, c = 'orange', label = "mm_2")
plt.plot(ghistorybits, fp_1, c = 'r', label = "fp_1")
plt.plot(ghistorybits, fp_2, c = 'black', label = "fp_2")

plt.xticks(ghistorybits)
plt.xlabel("#gHistoryBits")
plt.ylabel("Misprediction Rate (%)")
plt.title("Gshare: Misprediction rate against choice of #gHistoryBits")
plt.legend()
plt.savefig('../report/ghare_hw_plot.pdf')  
plt.show()

# %% [markdown]
# # Tournament: misprediction rate plots for different traces and configs

# %%
configs = ["5:6:6", "6:7:7", "7:8:8", "8:9:9", "9:10:10", "10:11:11", "11:12:12", "12:13:13", "13:14:14", "14:15:15", "15:16:16"]

int_1_t = [27.83, 23.58, 19.26, 14.96, 12.62, 10.99, 10.17, 9.61, 9.17, 8.89, 8.65]
int_2_t = [1.08, 0.82, 0.58, 0.47, 0.43, 0.37, 0.33, 0.325, 0.297, 0.29, 0.28]

mm_1_t = [22.73, 17.21, 10.93, 6.25, 2.58, 1.7, 1.07, 0.92, 0.62, 0.49, 0.42]
mm_2_t = [17.77, 14.7, 11.88, 10, 8.48, 7.58, 6.96, 6.41, 5.86, 5.44, 5.1]

fp_1_t = [1.73, 1.48, 0.99, 0.992, 0.991, 0.990, 0.990, 0.991, 0.992, 0.993, 0.995]
fp_2_t = [5.78, 5.38, 4.01, 3.08, 3.25, 2.48, 0.41, 0.411, 0.412, 0.410, 0.39]

# %%
# make plot for tournament 
plt.figure(figsize=(11, 6), dpi=200)
plt.plot(configs, int_1_t, c = 'b', label = "int_1")
plt.plot(configs, int_2_t, c = 'g', label = "int_2")
plt.plot(configs, mm_1_t, c = 'y', label = "mm_1")
plt.plot(configs, mm_2_t, c = 'orange', label = "mm_2")
plt.plot(configs, fp_1_t, c = 'r', label = "fp_1")
plt.plot(configs, fp_2_t, c = 'black', label = "fp_2")

plt.xlabel("#gHistoryBits:#lHistoryBits:#pcIndexBits")
plt.ylabel("Misprediction Rate (%)")
plt.title("Tournament: Misprediction rate against choice of #gHistoryBits:#lHistoryBits:#pcIndexBits")
plt.legend()
plt.savefig('../report/tournament_hw_plot.pdf')  
plt.show()

# %% [markdown]
# # Perceptron: misprediction rate plots for different traces and configs

# %%
# complete for perceptron once implementation is complete
# weight_bit_limit:num_weights_bits:perceptron_table_length_bits:0
configs_p = ["3:4:9", "3:5:8", "3:6:7", "3:7:6", "4:5:7", "4:7:5", "4:4:8", "4:6:6", "5:5:6", "5:6:5", "6:5:5", "6:4:6"]

int_1_p = [16.53, 12.725, 14.475, 14.699, 14.766, 20.615, 16.633, 16.473, 16.862, 21.816, 22.211, 20.888]
int_2_p = [0.471, 0.458, 0.505, 0.528, 0.466, 0.594, 0.471, 0.523, 0.485, 0.609, 0.571, 0.597]

mm_1_p = [6.837, 3.786, 3.764, 2.955, 3.848, 5.622, 6.837, 3.993, 3.998, 6.911, 7.476, 7.947]
mm_2_p = [8.575, 8.365, 9.698, 10.962, 9.495, 12.972, 8.575, 11.286, 10.951, 13.455, 13.118, 11.208]

fp_1_p = [1, 1.287, 1.368, 1.428, 1.346, 1.603, 1, 1.223, 1.363, 1.456, 1.466, 1.292]
fp_2_p = [1.295, 1.702, 1.709, 1.72, 1.704, 1.907, 1.295, 1.723, 1.747, 1.906, 1.897, 1.610]

# %%
# make plot for tournament 
plt.figure(figsize=(11, 6), dpi=200)
plt.plot(configs_p, int_1_p, c = 'b', label = "int_1")
plt.plot(configs_p, int_2_p, c = 'g', label = "int_2")
plt.plot(configs_p, mm_1_p, c = 'y', label = "mm_1")
plt.plot(configs_p, mm_2_p, c = 'orange', label = "mm_2")
plt.plot(configs_p, fp_1_p, c = 'r', label = "fp_1")
plt.plot(configs_p, fp_2_p, c = 'black', label = "fp_2")

plt.xlabel("Perceptron parameters")
plt.ylabel("Misprediction Rate (%)")
plt.title("Perceptron (Custom): Misprediction rate against choice of w:n:t:0")
plt.legend()
plt.savefig('../report/perceptron_hw_plot.pdf')
plt.show()

# %%
# More perceptron experiments - choose optimal theta
theta = [0, 2, 4, 8, 16, 32, 64, 128, 256]
theta = [str(i) for i in theta]

int_1_p2 = [12.725, 12.332, 12.009, 11.477, 10.730, 9.983, 9.452, 9.228, 9.269]
int_2_p2 = [0.458, 0.439, 0.415, 0.398, 0.343, 0.306, 0.297, 0.311, 0.337]

mm_1_p2 = [3.786, 3.691, 3.661, 3.517, 3.185, 3.045, 2.933, 3.026, 3.054]
mm_2_p2 = [8.365, 8.11, 7.92, 7.658, 7.401, 7.296, 7.454, 7.860, 8.486]

fp_1_p2 = [1.287, 0.951, 0.909, 0.838, 0.822, 0.822, 0.824, 0.829, 0.833]
fp_2_p2 = [1.702, 1.425, 1.740, 1.647, 1.085, 0.961, 0.963, 0.968, 0.977]

# %%
# make plot for tournament 
plt.figure(figsize=(11, 6), dpi=200)
plt.plot(theta, int_1_p2, c = 'b', label = "int_1")
plt.plot(theta, int_2_p2, c = 'g', label = "int_2")
plt.plot(theta, mm_1_p2, c = 'y', label = "mm_1")
plt.plot(theta, mm_2_p2, c = 'orange', label = "mm_2")
plt.plot(theta, fp_1_p2, c = 'r', label = "fp_1")
plt.plot(theta, fp_2_p2, c = 'black', label = "fp_2")

plt.xlabel("Theta")
plt.ylabel("Misprediction Rate (%)")
plt.xticks(theta)
plt.title("Perceptron (Custom): Misprediction rate against choice of 3:5:8:theta")
plt.legend()
plt.savefig('../report/plots/perceptron_hw_theta_plot.pdf')
plt.show()

# %% [markdown]
# ## CLI dump of results used to generate plots

# %% [markdown]
# # gshare, int_1
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:5
# Branches:           3771697
# Incorrect:          1341729
# Misprediction Rate:  35.574
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:6
# Branches:           3771697
# Incorrect:          1355650
# Misprediction Rate:  35.943
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:7
# Branches:           3771697
# Incorrect:          1291011
# Misprediction Rate:  34.229
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:8
# Branches:           3771697
# Incorrect:          1165757
# Misprediction Rate:  30.908
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:9
# Branches:           3771697
# Incorrect:           984936
# Misprediction Rate:  26.114
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:10
# Branches:           3771697
# Incorrect:           830671
# Misprediction Rate:  22.024
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:11
# Branches:           3771697
# Incorrect:           718487
# Misprediction Rate:  19.049
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:12
# Branches:           3771697
# Incorrect:           610680
# Misprediction Rate:  16.191
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:13
# Branches:           3771697
# Incorrect:           521958
# Misprediction Rate:  13.839
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:14
# Branches:           3771697
# Incorrect:           460107
# Misprediction Rate:  12.199
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --gshare:15
# Branches:           3771697
# Incorrect:           423190
# Misprediction Rate:  11.220

# %% [markdown]
# # gshare, int_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:5
# Branches:           3755315
# Incorrect:            74178
# Misprediction Rate:   1.975
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:6
# Branches:           3755315
# Incorrect:            64223
# Misprediction Rate:   1.710
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:7
# Branches:           3755315
# Incorrect:            57757
# Misprediction Rate:   1.538
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:8
# Branches:           3755315
# Incorrect:            47114
# Misprediction Rate:   1.255
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:9
# Branches:           3755315
# Incorrect:            36354
# Misprediction Rate:   0.968
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:10
# Branches:           3755315
# Incorrect:            27551
# Misprediction Rate:   0.734
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:11
# Branches:           3755315
# Incorrect:            21875
# Misprediction Rate:   0.583
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:12
# Branches:           3755315
# Incorrect:            18638
# Misprediction Rate:   0.496
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:13
# Branches:           3755315
# Incorrect:            15776
# Misprediction Rate:   0.420
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:14
# Branches:           3755315
# Incorrect:            15071
# Misprediction Rate:   0.401
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --gshare:15
# Branches:           3755315
# Incorrect:            13678
# Misprediction Rate:   0.364

# %% [markdown]
# # gshare mm_1
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:5
# Branches:           3014850
# Incorrect:           942193
# Misprediction Rate:  31.252
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:6
# Branches:           3014850
# Incorrect:           901356
# Misprediction Rate:  29.897
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:7
# Branches:           3014850
# Incorrect:           823300
# Misprediction Rate:  27.308
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:8
# Branches:           3014850
# Incorrect:           678340
# Misprediction Rate:  22.500
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:9
# Branches:           3014850
# Incorrect:           501858
# Misprediction Rate:  16.646
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:10
# Branches:           3014850
# Incorrect:           395065
# Misprediction Rate:  13.104
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:11
# Branches:           3014850
# Incorrect:           298194
# Misprediction Rate:   9.891
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:12
# Branches:           3014850
# Incorrect:           237693
# Misprediction Rate:   7.884
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:13
# Branches:           3014850
# Incorrect:           201871
# Misprediction Rate:   6.696
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:14
# Branches:           3014850
# Incorrect:           160795
# Misprediction Rate:   5.333
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --gshare:15
# Branches:           3014850
# Incorrect:           133899
# Misprediction Rate:   4.441

# %% [markdown]
# # gshare mm_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:5
# Branches:           2563897
# Incorrect:           617741
# Misprediction Rate:  24.094
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:6
# Branches:           2563897
# Incorrect:           548874
# Misprediction Rate:  21.408
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:7
# Branches:           2563897
# Incorrect:           503359
# Misprediction Rate:  19.633
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:8
# Branches:           2563897
# Incorrect:           452097
# Misprediction Rate:  17.633
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:9
# Branches:           2563897
# Incorrect:           388610
# Misprediction Rate:  15.157
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:10
# Branches:           2563897
# Incorrect:           341369
# Misprediction Rate:  13.314
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:11
# Branches:           2563897
# Incorrect:           305415
# Misprediction Rate:  11.912
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:12
# Branches:           2563897
# Incorrect:           280387
# Misprediction Rate:  10.936
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:13
# Branches:           2563897
# Incorrect:           259929
# Misprediction Rate:  10.138
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:14
# Branches:           2563897
# Incorrect:           233162
# Misprediction Rate:   9.094
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --gshare:15
# Branches:           2563897
# Incorrect:           206100
# Misprediction Rate:   8.039

# %% [markdown]
# # gshare, fp_1
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:5
# Branches:           1546797
# Incorrect:            41384
# Misprediction Rate:   2.675
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:6
# Branches:           1546797
# Incorrect:            35656
# Misprediction Rate:   2.305
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:7
# Branches:           1546797
# Incorrect:            28614
# Misprediction Rate:   1.850
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:8
# Branches:           1546797
# Incorrect:            25448
# Misprediction Rate:   1.645
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:9
# Branches:           1546797
# Incorrect:            22681
# Misprediction Rate:   1.466
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:10
# Branches:           1546797
# Incorrect:            18865
# Misprediction Rate:   1.220
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:11
# Branches:           1546797
# Incorrect:            18153
# Misprediction Rate:   1.174
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:12
# Branches:           1546797
# Incorrect:            15452
# Misprediction Rate:   0.999
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:13
# Branches:           1546797
# Incorrect:            12765
# Misprediction Rate:   0.825
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:14
# Branches:           1546797
# Incorrect:            12770
# Misprediction Rate:   0.826
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --gshare:15
# Branches:           1546797
# Incorrect:            12789
# Misprediction Rate:   0.827

# %% [markdown]
# # gshare, fp_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:5
# Branches:           2422049
# Incorrect:           474519
# Misprediction Rate:  19.592
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:6
# Branches:           2422049
# Incorrect:           427268
# Misprediction Rate:  17.641
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:7
# Branches:           2422049
# Incorrect:           367818
# Misprediction Rate:  15.186
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:8
# Branches:           2422049
# Incorrect:           277223
# Misprediction Rate:  11.446
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:9
# Branches:           2422049
# Incorrect:           259954
# Misprediction Rate:  10.733
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:10
# Branches:           2422049
# Incorrect:           148486
# Misprediction Rate:   6.131
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:11
# Branches:           2422049
# Incorrect:           130632
# Misprediction Rate:   5.393
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:12
# Branches:           2422049
# Incorrect:            81446
# Misprediction Rate:   3.363
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:13
# Branches:           2422049
# Incorrect:            40641
# Misprediction Rate:   1.678
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:14
# Branches:           2422049
# Incorrect:            32820
# Misprediction Rate:   1.355
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --gshare:15
# Branches:           2422049
# Incorrect:            23855
# Misprediction Rate:   0.985

# %% [markdown]
# # tournament, int_1
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:5:6:6
# Branches:           3771697
# Incorrect:          1049775
# Misprediction Rate:  27.833
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:6:7:7
# Branches:           3771697
# Incorrect:           889472
# Misprediction Rate:  23.583
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:7:8:8
# Branches:           3771697
# Incorrect:           726594
# Misprediction Rate:  19.264
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:8:9:9
# Branches:           3771697
# Incorrect:           564112
# Misprediction Rate:  14.956
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:9:10:10
# Branches:           3771697
# Incorrect:           476073
# Misprediction Rate:  12.622
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:10:11:11
# Branches:           3771697
# Incorrect:           414836
# Misprediction Rate:  10.999
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:11:12:12
# Branches:           3771697
# Incorrect:           383636
# Misprediction Rate:  10.171
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:12:13:13
# Branches:           3771697
# Incorrect:           362601
# Misprediction Rate:   9.614
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:13:14:14
# Branches:           3771697
# Incorrect:           345966
# Misprediction Rate:   9.173
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:14:15:15
# Branches:           3771697
# Incorrect:           335160
# Misprediction Rate:   8.886
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_1.bz2 | ./predictor --tournament:15:16:16
# Branches:           3771697
# Incorrect:           326330
# Misprediction Rate:   8.652

# %% [markdown]
# # tournament, int_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:5:6:6
# Branches:           3755315
# Incorrect:            40588
# Misprediction Rate:   1.081
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:6:7:7
# Branches:           3755315
# Incorrect:            30691
# Misprediction Rate:   0.817
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:7:8:8
# Branches:           3755315
# Incorrect:            21915
# Misprediction Rate:   0.584
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:8:9:9
# Branches:           3755315
# Incorrect:            17771
# Misprediction Rate:   0.473
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:9:10:10
# Branches:           3755315
# Incorrect:            15980
# Misprediction Rate:   0.426
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:10:11:11
# Branches:           3755315
# Incorrect:            13954
# Misprediction Rate:   0.372
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:11:12:12
# Branches:           3755315
# Incorrect:            12511
# Misprediction Rate:   0.333
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:12:13:13
# Branches:           3755315
# Incorrect:            12200
# Misprediction Rate:   0.325
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:13:14:14
# Branches:           3755315
# Incorrect:            11163
# Misprediction Rate:   0.297
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:14:15:15
# Branches:           3755315
# Incorrect:            10878
# Misprediction Rate:   0.290
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/int_2.bz2 | ./predictor --tournament:15:16:16
# Branches:           3755315
# Incorrect:            10618
# Misprediction Rate:   0.283

# %% [markdown]
# # tournament, mm_1
#
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:5:6:6
# Branches:           3014850
# Incorrect:           685162
# Misprediction Rate:  22.726
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:6:7:7
# Branches:           3014850
# Incorrect:           518877
# Misprediction Rate:  17.211
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:7:8:8
# Branches:           3014850
# Incorrect:           329533
# Misprediction Rate:  10.930
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:8:9:9
# Branches:           3014850
# Incorrect:           188341
# Misprediction Rate:   6.247
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:9:10:10
# Branches:           3014850
# Incorrect:            77802
# Misprediction Rate:   2.581
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:10:11:11
# Branches:           3014850
# Incorrect:            51493
# Misprediction Rate:   1.708
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:11:12:12
# Branches:           3014850
# Incorrect:            32307
# Misprediction Rate:   1.072
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:12:13:13
# Branches:           3014850
# Incorrect:            27855
# Misprediction Rate:   0.924
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:13:14:14
# Branches:           3014850
# Incorrect:            18602
# Misprediction Rate:   0.617
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:14:15:15
# Branches:           3014850
# Incorrect:            15017
# Misprediction Rate:   0.498
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_1.bz2 | ./predictor --tournament:15:16:16
# Branches:           3014850
# Incorrect:            12734
# Misprediction Rate:   0.422

# %% [markdown]
# # tournament, mm_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:5:6:6
# Branches:           2563897
# Incorrect:           455547
# Misprediction Rate:  17.768
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:6:7:7
# Branches:           2563897
# Incorrect:           378215
# Misprediction Rate:  14.752
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:7:8:8
# Branches:           2563897
# Incorrect:           304559
# Misprediction Rate:  11.879
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:8:9:9
# Branches:           2563897
# Incorrect:           256607
# Misprediction Rate:  10.008
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:9:10:10
# Branches:           2563897
# Incorrect:           217501
# Misprediction Rate:   8.483
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:10:11:11
# Branches:           2563897
# Incorrect:           194345
# Misprediction Rate:   7.580
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:11:12:12
# Branches:           2563897
# Incorrect:           178621
# Misprediction Rate:   6.967
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:12:13:13
# Branches:           2563897
# Incorrect:           164213
# Misprediction Rate:   6.405
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:13:14:14
# Branches:           2563897
# Incorrect:           150323
# Misprediction Rate:   5.863
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:14:15:15
# Branches:           2563897
# Incorrect:           139498
# Misprediction Rate:   5.441
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/mm_2.bz2 | ./predictor --tournament:15:16:16
# Branches:           2563897
# Incorrect:           130687
# Misprediction Rate:   5.097

# %% [markdown]
# # tournament, fp_1
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:5:6:6
# Branches:           1546797
# Incorrect:            26805
# Misprediction Rate:   1.733
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:6:7:7
# Branches:           1546797
# Incorrect:            22884
# Misprediction Rate:   1.479
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:7:8:8
# Branches:           1546797
# Incorrect:            15424
# Misprediction Rate:   0.997
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:8:9:9
# Branches:           1546797
# Incorrect:            15348
# Misprediction Rate:   0.992
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:9:10:10
# Branches:           1546797
# Incorrect:            15329
# Misprediction Rate:   0.991
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:10:11:11
# Branches:           1546797
# Incorrect:            15313
# Misprediction Rate:   0.990
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:11:12:12
# Branches:           1546797
# Incorrect:            15313
# Misprediction Rate:   0.990
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:12:13:13
# Branches:           1546797
# Incorrect:            15333
# Misprediction Rate:   0.991
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:13:14:14
# Branches:           1546797
# Incorrect:            15349
# Misprediction Rate:   0.992
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:14:15:15
# Branches:           1546797
# Incorrect:            15365
# Misprediction Rate:   0.993
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_1.bz2 | ./predictor --tournament:15:16:16
# Branches:           1546797
# Incorrect:            15388
# Misprediction Rate:   0.995

# %% [markdown]
# # tournament fp_2
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:5:6:6
# Branches:           2422049
# Incorrect:           139994
# Misprediction Rate:   5.780
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:6:7:7
# Branches:           2422049
# Incorrect:           130336
# Misprediction Rate:   5.381
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:7:8:8
# Branches:           2422049
# Incorrect:            97085
# Misprediction Rate:   4.008
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:8:9:9
# Branches:           2422049
# Incorrect:            74684
# Misprediction Rate:   3.084
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:9:10:10
# Branches:           2422049
# Incorrect:            78619
# Misprediction Rate:   3.246
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:10:11:11
# Branches:           2422049
# Incorrect:            60119
# Misprediction Rate:   2.482
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:11:12:12
# Branches:           2422049
# Incorrect:             9933
# Misprediction Rate:   0.410
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:12:13:13
# Branches:           2422049
# Incorrect:             9949
# Misprediction Rate:   0.411
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:13:14:14
# Branches:           2422049
# Incorrect:             9968
# Misprediction Rate:   0.412
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:14:15:15
# Branches:           2422049
# Incorrect:             9984
# Misprediction Rate:   0.412
#
# root@b90a841b32ed:/home/branch_predictor/src# bunzip2 -kc ../traces/fp_2.bz2 | ./predictor --tournament:15:16:16
# Branches:           2422049
# Incorrect:             9445
# Misprediction Rate:   0.390

# %% [markdown]
# # perceptron ALL
#
# root@b90a841b32ed:/home/branch_predictor/src# sh ./run_perceptron.sh 3:4:9:0 3:5:8:0 3:6:7:0 3:7:6:0 4:5:7:0 4:7:5:0 4:4:8:0 4:6:6:0 5:5:6:0 5:6:5:0 6:5:5:0 6:4:6:0
#
# For int_1 trace and configuration: 3:4:9:0
# Branches:           3771697
# Incorrect:           627357
# Misprediction Rate:  16.633
#
# For int_1 trace and configuration: 3:5:8:0
# Branches:           3771697
# Incorrect:           479952
# Misprediction Rate:  12.725
#
# For int_1 trace and configuration: 3:6:7:0
# Branches:           3771697
# Incorrect:           545964
# Misprediction Rate:  14.475
#
# For int_1 trace and configuration: 3:7:6:0
# Branches:           3771697
# Incorrect:           554390
# Misprediction Rate:  14.699
#
# For int_1 trace and configuration: 4:5:7:0
# Branches:           3771697
# Incorrect:           556942
# Misprediction Rate:  14.766
#
# For int_1 trace and configuration: 4:7:5:0
# Branches:           3771697
# Incorrect:           777547
# Misprediction Rate:  20.615
#
# For int_1 trace and configuration: 4:4:8:0
# Branches:           3771697
# Incorrect:           627357
# Misprediction Rate:  16.633
#
# For int_1 trace and configuration: 4:6:6:0
# Branches:           3771697
# Incorrect:           621310
# Misprediction Rate:  16.473
#
# For int_1 trace and configuration: 5:5:6:0
# Branches:           3771697
# Incorrect:           635982
# Misprediction Rate:  16.862
#
# For int_1 trace and configuration: 5:6:5:0
# Branches:           3771697
# Incorrect:           822834
# Misprediction Rate:  21.816
#
# For int_1 trace and configuration: 6:5:5:0
# Branches:           3771697
# Incorrect:           837732
# Misprediction Rate:  22.211
#
# For int_1 trace and configuration: 6:4:6:0
# Branches:           3771697
# Incorrect:           787835
# Misprediction Rate:  20.888
#
# int_1 is done, now running for int_2
#
#
# For int_2 trace and configuration: 3:4:9:0
# Branches:           3755315
# Incorrect:            17697
# Misprediction Rate:   0.471
#
# For int_2 trace and configuration: 3:5:8:0
# Branches:           3755315
# Incorrect:            17194
# Misprediction Rate:   0.458
#
# For int_2 trace and configuration: 3:6:7:0
# Branches:           3755315
# Incorrect:            18969
# Misprediction Rate:   0.505
#
# For int_2 trace and configuration: 3:7:6:0
# Branches:           3755315
# Incorrect:            19826
# Misprediction Rate:   0.528
#
# For int_2 trace and configuration: 4:5:7:0
# Branches:           3755315
# Incorrect:            17500
# Misprediction Rate:   0.466
#
# For int_2 trace and configuration: 4:7:5:0
# Branches:           3755315
# Incorrect:            22300
# Misprediction Rate:   0.594
#
# For int_2 trace and configuration: 4:4:8:0
# Branches:           3755315
# Incorrect:            17697
# Misprediction Rate:   0.471
#
# For int_2 trace and configuration: 4:6:6:0
# Branches:           3755315
# Incorrect:            19637
# Misprediction Rate:   0.523
#
# For int_2 trace and configuration: 5:5:6:0
# Branches:           3755315
# Incorrect:            18212
# Misprediction Rate:   0.485
#
# For int_2 trace and configuration: 5:6:5:0
# Branches:           3755315
# Incorrect:            22886
# Misprediction Rate:   0.609
#
# For int_2 trace and configuration: 6:5:5:0
# Branches:           3755315
# Incorrect:            21446
# Misprediction Rate:   0.571
#
# For int_2 trace and configuration: 6:4:6:0
# Branches:           3755315
# Incorrect:            22416
# Misprediction Rate:   0.597
#
# int_2 is done, now running for mm_1
#
#
# For mm_1 trace and configuration: 3:4:9:0
# Branches:           3014850
# Incorrect:           206128
# Misprediction Rate:   6.837
#
# For mm_1 trace and configuration: 3:5:8:0
# Branches:           3014850
# Incorrect:           114150
# Misprediction Rate:   3.786
#
# For mm_1 trace and configuration: 3:6:7:0
# Branches:           3014850
# Incorrect:           113489
# Misprediction Rate:   3.764
#
# For mm_1 trace and configuration: 3:7:6:0
# Branches:           3014850
# Incorrect:            89099
# Misprediction Rate:   2.955
#
# For mm_1 trace and configuration: 4:5:7:0
# Branches:           3014850
# Incorrect:           116017
# Misprediction Rate:   3.848
#
# For mm_1 trace and configuration: 4:7:5:0
# Branches:           3014850
# Incorrect:           169499
# Misprediction Rate:   5.622
#
# For mm_1 trace and configuration: 4:4:8:0
# Branches:           3014850
# Incorrect:           206128
# Misprediction Rate:   6.837
#
# For mm_1 trace and configuration: 4:6:6:0
# Branches:           3014850
# Incorrect:           120368
# Misprediction Rate:   3.993
#
# For mm_1 trace and configuration: 5:5:6:0
# Branches:           3014850
# Incorrect:           120535
# Misprediction Rate:   3.998
#
# For mm_1 trace and configuration: 5:6:5:0
# Branches:           3014850
# Incorrect:           208349
# Misprediction Rate:   6.911
#
# For mm_1 trace and configuration: 6:5:5:0
# Branches:           3014850
# Incorrect:           225386
# Misprediction Rate:   7.476
#
# For mm_1 trace and configuration: 6:4:6:0
# Branches:           3014850
# Incorrect:           239586
# Misprediction Rate:   7.947
#
# mm_1 is done, now running for mm_2
#
#
# For mm_2 trace and configuration: 3:4:9:0
# Branches:           2563897
# Incorrect:           219856
# Misprediction Rate:   8.575
#
# For mm_2 trace and configuration: 3:5:8:0
# Branches:           2563897
# Incorrect:           214477
# Misprediction Rate:   8.365
#
# For mm_2 trace and configuration: 3:6:7:0
# Branches:           2563897
# Incorrect:           248643
# Misprediction Rate:   9.698
#
# For mm_2 trace and configuration: 3:7:6:0
# Branches:           2563897
# Incorrect:           281058
# Misprediction Rate:  10.962
#
# For mm_2 trace and configuration: 4:5:7:0
# Branches:           2563897
# Incorrect:           243445
# Misprediction Rate:   9.495
#
# For mm_2 trace and configuration: 4:7:5:0
# Branches:           2563897
# Incorrect:           332587
# Misprediction Rate:  12.972
#
# For mm_2 trace and configuration: 4:4:8:0
# Branches:           2563897
# Incorrect:           219856
# Misprediction Rate:   8.575
#
# For mm_2 trace and configuration: 4:6:6:0
# Branches:           2563897
# Incorrect:           289366
# Misprediction Rate:  11.286
#
# For mm_2 trace and configuration: 5:5:6:0
# Branches:           2563897
# Incorrect:           280784
# Misprediction Rate:  10.951
#
# For mm_2 trace and configuration: 5:6:5:0
# Branches:           2563897
# Incorrect:           344976
# Misprediction Rate:  13.455
#
# For mm_2 trace and configuration: 6:5:5:0
# Branches:           2563897
# Incorrect:           336328
# Misprediction Rate:  13.118
#
# For mm_2 trace and configuration: 6:4:6:0
# Branches:           2563897
# Incorrect:           287352
# Misprediction Rate:  11.208
#
# mm_2 is done, now running for fp_1
#
#
# For fp_1 trace and configuration: 3:4:9:0
# Branches:           1546797
# Incorrect:            15509
# Misprediction Rate:   1.003
#
# For fp_1 trace and configuration: 3:5:8:0
# Branches:           1546797
# Incorrect:            19909
# Misprediction Rate:   1.287
#
# For fp_1 trace and configuration: 3:6:7:0
# Branches:           1546797
# Incorrect:            21166
# Misprediction Rate:   1.368
#
# For fp_1 trace and configuration: 3:7:6:0
# Branches:           1546797
# Incorrect:            22095
# Misprediction Rate:   1.428
#
# For fp_1 trace and configuration: 4:5:7:0
# Branches:           1546797
# Incorrect:            20816
# Misprediction Rate:   1.346
#
# For fp_1 trace and configuration: 4:7:5:0
# Branches:           1546797
# Incorrect:            24788
# Misprediction Rate:   1.603
#
# For fp_1 trace and configuration: 4:4:8:0
# Branches:           1546797
# Incorrect:            15509
# Misprediction Rate:   1.003
#
# For fp_1 trace and configuration: 4:6:6:0
# Branches:           1546797
# Incorrect:            18913
# Misprediction Rate:   1.223
#
# For fp_1 trace and configuration: 5:5:6:0
# Branches:           1546797
# Incorrect:            21077
# Misprediction Rate:   1.363
#
# For fp_1 trace and configuration: 5:6:5:0
# Branches:           1546797
# Incorrect:            22518
# Misprediction Rate:   1.456
#
# For fp_1 trace and configuration: 6:5:5:0
# Branches:           1546797
# Incorrect:            22669
# Misprediction Rate:   1.466
#
# For fp_1 trace and configuration: 6:4:6:0
# Branches:           1546797
# Incorrect:            19991
# Misprediction Rate:   1.292
#
# fp_1 is done, now running for fp_2
#
#
# For fp_2 trace and configuration: 3:4:9:0
# Branches:           2422049
# Incorrect:            31366
# Misprediction Rate:   1.295
#
# For fp_2 trace and configuration: 3:5:8:0
# Branches:           2422049
# Incorrect:            41222
# Misprediction Rate:   1.702
#
# For fp_2 trace and configuration: 3:6:7:0
# Branches:           2422049
# Incorrect:            41391
# Misprediction Rate:   1.709
#
# For fp_2 trace and configuration: 3:7:6:0
# Branches:           2422049
# Incorrect:            41654
# Misprediction Rate:   1.720
#
# For fp_2 trace and configuration: 4:5:7:0
# Branches:           2422049
# Incorrect:            41270
# Misprediction Rate:   1.704
#
# For fp_2 trace and configuration: 4:7:5:0
# Branches:           2422049
# Incorrect:            46196
# Misprediction Rate:   1.907
#
# For fp_2 trace and configuration: 4:4:8:0
# Branches:           2422049
# Incorrect:            31366
# Misprediction Rate:   1.295
#
# For fp_2 trace and configuration: 4:6:6:0
# Branches:           2422049
# Incorrect:            41721
# Misprediction Rate:   1.723
#
# For fp_2 trace and configuration: 5:5:6:0
# Branches:           2422049
# Incorrect:            42303
# Misprediction Rate:   1.747
#
# For fp_2 trace and configuration: 5:6:5:0
# Branches:           2422049
# Incorrect:            46171
# Misprediction Rate:   1.906
#
# For fp_2 trace and configuration: 6:5:5:0
# Branches:           2422049
# Incorrect:            45942
# Misprediction Rate:   1.897
#
# For fp_2 trace and configuration: 6:4:6:0
# Branches:           2422049
# Incorrect:            38984
# Misprediction Rate:   1.610
# root@b90a841b32ed:/home/branch_predictor/src#

# %% [markdown]
# # perceptron theta
#
# root@b90a841b32ed:/home/branch_predictor/src# sh ./run_perceptron.sh 3:5:8:0 3:5:8:2 3:5:8:4 3:5:8:8 3:5:8:16 3:5:8:32 3:5:8:64 3:5:8:128 3:5:8:256
#
# For int_1 trace and configuration: 3:5:8:0
# Branches:           3771697
# Incorrect:           479952
# Misprediction Rate:  12.725
#
# For int_1 trace and configuration: 3:5:8:2
# Branches:           3771697
# Incorrect:           465130
# Misprediction Rate:  12.332
#
# For int_1 trace and configuration: 3:5:8:4
# Branches:           3771697
# Incorrect:           452935
# Misprediction Rate:  12.009
#
# For int_1 trace and configuration: 3:5:8:8
# Branches:           3771697
# Incorrect:           432872
# Misprediction Rate:  11.477
#
# For int_1 trace and configuration: 3:5:8:16
# Branches:           3771697
# Incorrect:           404690
# Misprediction Rate:  10.730
#
# For int_1 trace and configuration: 3:5:8:32
# Branches:           3771697
# Incorrect:           376534
# Misprediction Rate:   9.983
#
# For int_1 trace and configuration: 3:5:8:64
# Branches:           3771697
# Incorrect:           356511
# Misprediction Rate:   9.452
#
# For int_1 trace and configuration: 3:5:8:128
# Branches:           3771697
# Incorrect:           348068
# Misprediction Rate:   9.228
#
# For int_1 trace and configuration: 3:5:8:256
# Branches:           3771697
# Incorrect:           349613
# Misprediction Rate:   9.269
#
# int_1 is done, now running for int_2
#
#
# For int_2 trace and configuration: 3:5:8:0
# Branches:           3755315
# Incorrect:            17194
# Misprediction Rate:   0.458
#
# For int_2 trace and configuration: 3:5:8:2
# Branches:           3755315
# Incorrect:            16469
# Misprediction Rate:   0.439
#
# For int_2 trace and configuration: 3:5:8:4
# Branches:           3755315
# Incorrect:            15575
# Misprediction Rate:   0.415
#
# For int_2 trace and configuration: 3:5:8:8
# Branches:           3755315
# Incorrect:            14935
# Misprediction Rate:   0.398
#
# For int_2 trace and configuration: 3:5:8:16
# Branches:           3755315
# Incorrect:            12873
# Misprediction Rate:   0.343
#
# For int_2 trace and configuration: 3:5:8:32
# Branches:           3755315
# Incorrect:            11481
# Misprediction Rate:   0.306
#
# For int_2 trace and configuration: 3:5:8:64
# Branches:           3755315
# Incorrect:            11157
# Misprediction Rate:   0.297
#
# For int_2 trace and configuration: 3:5:8:128
# Branches:           3755315
# Incorrect:            11671
# Misprediction Rate:   0.311
#
# For int_2 trace and configuration: 3:5:8:256
# Branches:           3755315
# Incorrect:            12671
# Misprediction Rate:   0.337
#
# int_2 is done, now running for mm_1
#
#
# For mm_1 trace and configuration: 3:5:8:0
# Branches:           3014850
# Incorrect:           114150
# Misprediction Rate:   3.786
#
# For mm_1 trace and configuration: 3:5:8:2
# Branches:           3014850
# Incorrect:           111291
# Misprediction Rate:   3.691
#
# For mm_1 trace and configuration: 3:5:8:4
# Branches:           3014850
# Incorrect:           110373
# Misprediction Rate:   3.661
#
# For mm_1 trace and configuration: 3:5:8:8
# Branches:           3014850
# Incorrect:           106024
# Misprediction Rate:   3.517
#
# For mm_1 trace and configuration: 3:5:8:16
# Branches:           3014850
# Incorrect:            96013
# Misprediction Rate:   3.185
#
# For mm_1 trace and configuration: 3:5:8:32
# Branches:           3014850
# Incorrect:            91812
# Misprediction Rate:   3.045
#
# For mm_1 trace and configuration: 3:5:8:64
# Branches:           3014850
# Incorrect:            88417
# Misprediction Rate:   2.933
#
# For mm_1 trace and configuration: 3:5:8:128
# Branches:           3014850
# Incorrect:            91241
# Misprediction Rate:   3.026
#
# For mm_1 trace and configuration: 3:5:8:256
# Branches:           3014850
# Incorrect:            92078
# Misprediction Rate:   3.054
#
# mm_1 is done, now running for mm_2
#
#
# For mm_2 trace and configuration: 3:5:8:0
# Branches:           2563897
# Incorrect:           214477
# Misprediction Rate:   8.365
#
# For mm_2 trace and configuration: 3:5:8:2
# Branches:           2563897
# Incorrect:           207940
# Misprediction Rate:   8.110
#
# For mm_2 trace and configuration: 3:5:8:4
# Branches:           2563897
# Incorrect:           203069
# Misprediction Rate:   7.920
#
# For mm_2 trace and configuration: 3:5:8:8
# Branches:           2563897
# Incorrect:           196350
# Misprediction Rate:   7.658
#
# For mm_2 trace and configuration: 3:5:8:16
# Branches:           2563897
# Incorrect:           189755
# Misprediction Rate:   7.401
#
# For mm_2 trace and configuration: 3:5:8:32
# Branches:           2563897
# Incorrect:           187070
# Misprediction Rate:   7.296
#
# For mm_2 trace and configuration: 3:5:8:64
# Branches:           2563897
# Incorrect:           191110
# Misprediction Rate:   7.454
#
# For mm_2 trace and configuration: 3:5:8:128
# Branches:           2563897
# Incorrect:           201528
# Misprediction Rate:   7.860
#
# For mm_2 trace and configuration: 3:5:8:256
# Branches:           2563897
# Incorrect:           217578
# Misprediction Rate:   8.486
#
# mm_2 is done, now running for fp_1
#
#
# For fp_1 trace and configuration: 3:5:8:0
# Branches:           1546797
# Incorrect:            19909
# Misprediction Rate:   1.287
#
# For fp_1 trace and configuration: 3:5:8:2
# Branches:           1546797
# Incorrect:            14705
# Misprediction Rate:   0.951
#
# For fp_1 trace and configuration: 3:5:8:4
# Branches:           1546797
# Incorrect:            14055
# Misprediction Rate:   0.909
#
# For fp_1 trace and configuration: 3:5:8:8
# Branches:           1546797
# Incorrect:            12969
# Misprediction Rate:   0.838
#
# For fp_1 trace and configuration: 3:5:8:16
# Branches:           1546797
# Incorrect:            12709
# Misprediction Rate:   0.822
#
# For fp_1 trace and configuration: 3:5:8:32
# Branches:           1546797
# Incorrect:            12715
# Misprediction Rate:   0.822
#
# For fp_1 trace and configuration: 3:5:8:64
# Branches:           1546797
# Incorrect:            12754
# Misprediction Rate:   0.824
#
# For fp_1 trace and configuration: 3:5:8:128
# Branches:           1546797
# Incorrect:            12816
# Misprediction Rate:   0.829
#
# For fp_1 trace and configuration: 3:5:8:256
# Branches:           1546797
# Incorrect:            12889
# Misprediction Rate:   0.833
#
# fp_1 is done, now running for fp_2
#
#
# For fp_2 trace and configuration: 3:5:8:0
# Branches:           2422049
# Incorrect:            41222
# Misprediction Rate:   1.702
#
# For fp_2 trace and configuration: 3:5:8:2
# Branches:           2422049
# Incorrect:            34523
# Misprediction Rate:   1.425
#
# For fp_2 trace and configuration: 3:5:8:4
# Branches:           2422049
# Incorrect:            42154
# Misprediction Rate:   1.740
#
# For fp_2 trace and configuration: 3:5:8:8
# Branches:           2422049
# Incorrect:            39895
# Misprediction Rate:   1.647
#
# For fp_2 trace and configuration: 3:5:8:16
# Branches:           2422049
# Incorrect:            26272
# Misprediction Rate:   1.085
#
# For fp_2 trace and configuration: 3:5:8:32
# Branches:           2422049
# Incorrect:            23279
# Misprediction Rate:   0.961
#
# For fp_2 trace and configuration: 3:5:8:64
# Branches:           2422049
# Incorrect:            23328
# Misprediction Rate:   0.963
#
# For fp_2 trace and configuration: 3:5:8:128
# Branches:           2422049
# Incorrect:            23440
# Misprediction Rate:   0.968
#
# For fp_2 trace and configuration: 3:5:8:256
# Branches:           2422049
# Incorrect:            23665
# Misprediction Rate:   0.977
# root@b90a841b32ed:/home/branch_predictor/src#
